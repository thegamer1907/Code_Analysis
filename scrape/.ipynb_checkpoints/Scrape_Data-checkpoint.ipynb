# %%
import requests
from bs4 import BeautifulSoup
import os
import json

globalcnt = 1451
ignlist = []
totalusertype = {}

def init2():
    global totalusertype
    for i in range(1,1085):
        try:
            filename2 = 'E:\Codes\Code Analysis\CodesNew' + '\\' + str(i) + '.json'
            h = open(filename2)
            tp = json.load(h)
            h.close()
            try:
                totalusertype[tp["usertype"]]+=1          
            except:
                totalusertype[tp["usertype"]] = 1
        except:
            print('some error')

def html(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content,'html.parser')
    return soup

def processproblem(link,problink,exe,mem,usertype):
    global globalcnt
    page = html(link)
    pre = page.find_all('pre',class_='prettyprint lang-cpp program-source')
    code =  pre[0].text
    te = code.strip()
    ext = '.cpp'
    try:
        filename = 'E:\Codes\Code Analysis\CodesNew' + '\\' + str(globalcnt) + ext
        filename2 = 'E:\Codes\Code Analysis\CodesNew' + '\\' + str(globalcnt) + '.json'
        globalcnt+=1
        f = open(filename,"w")
        f.write(code)
        f.close()
        tdict = {}
        tdict["problemlink"] = problink
        tdict["sollink"] = link
        tdict["exec_time"] = exe
        tdict["memory"] = mem
        tdict["usertype"] = usertype
        g = open(filename2,"w")
        json.dump(tdict,g)
        g.close()
    except:
        print('error')


def eachpage(status_page,name):
    global ignlist
    global totalusertype
    status_table = status_page.findAll('table',class_='status-frame-datatable')
    tr = status_table[0].findAll('tr')
    tr.pop(0)
    for i in tr:
        td = i.findAll('td')
        sollink = 'https://www.codeforces.com' + td[0].a['href']
        usertype = td[2].a['title'].split(' ')[0]
        problemname = td[3].a.text.split('-')[-1].strip()
        lang = td[4].text.strip()
        exe = td[6].text.strip()
        mem = td[7].text.strip()
        problink = 'https://www.codeforces.com' + td[3].a['href']
        status = td[5].span['submissionverdict'].strip()
#         if usertype != 'Unrated,' and usertype != 'Pupil' and usertype != 'Specialist' and usertype != 'Newbie':
#             print(status,usertype,problemname,name,lang)
        if usertype not in ignlist:
            if lang == 'GNU C++17' or lang == 'GNU C++14' or lang == 'GNU C++11' or lang == 'GNU C++':
                if status == 'OK' and problemname == name:
                    try:
                        totalusertype[usertype]+=1
                        if totalusertype[usertype] > 200:
                            ignlist.append(usertype)
                    except:
                        totalusertype[usertype] = 1
                    processproblem(sollink,problink,exe,mem,usertype)
                    print(name,problemname)
    
    
                
                
    
def cfpage(page,name):
    global totalusertype
    contest_table = page.findAll('table',class_='rtable ')
    contest_url = contest_table[0].tbody.tr.a['href']
    contest_url = 'https://www.codeforces.com' + contest_url + '/status'
    status_page = html(contest_url)
    pagination = status_page.findAll('div',class_='pagination')
    li = pagination[1].ul.findAll('li')[-2]
    totpage = int(li.span.a.text)
    for i in range(1,min(totpage,200)):
        pageurl = contest_url + '/page/' + str(i) + '?order=BY_JUDGED_DESC'
        status_page = html(pageurl)
        eachpage(status_page,name)
        print('page done',i)
        print(totalusertype)

# %%
stopurl = 'https://www.stopstalk.com/problems/tag?page=1&generalized_tags=Binary+Search&site=CodeForces&orderby=solved-count-desc'

stopsoup = html(stopurl)
main_table = stopsoup.find_all('table',class_='bordered centered')
tbody = main_table[0].tbody
init2()
print(totalusertype)
tr = tbody.findAll('tr')

for j in range(26,len(tr)):
    i = tr[j]
    td = i.findAll('td')
    name = td[0].a.text.strip()
    purl = td[1].a['href']
    ppage = html(purl)
    cfpage(ppage,name)
    print('DONE WITH A PROBLEM')
# Out:
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# some error
# {'Expert': 153, 'Unrated,': 226, 'Newbie': 227, 'Specialist': 175, 'Pupil': 206, 'Candidate': 50, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 1
# {'Expert': 155, 'Unrated,': 226, 'Newbie': 227, 'Specialist': 176, 'Pupil': 207, 'Candidate': 50, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 2
# {'Expert': 156, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 177, 'Pupil': 207, 'Candidate': 51, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 3
# {'Expert': 158, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 180, 'Pupil': 207, 'Candidate': 51, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 4
# {'Expert': 160, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 181, 'Pupil': 207, 'Candidate': 51, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# page done 5
# {'Expert': 160, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 181, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# error
# Hamburgers Hamburgers
# page done 6
# {'Expert': 162, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 183, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 7
# {'Expert': 162, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 185, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 8
# {'Expert': 162, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 187, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 9
# {'Expert': 162, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 189, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# error
# Hamburgers Hamburgers
# error
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 10
# {'Expert': 162, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 194, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 11
# {'Expert': 162, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 196, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# page done 12
# {'Expert': 162, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 197, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 13
# {'Expert': 162, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 199, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# page done 14
# {'Expert': 162, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 200, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# page done 15
# {'Expert': 163, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 200, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# Hamburgers Hamburgers
# page done 16
# {'Expert': 166, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 201, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# page done 17
# {'Expert': 167, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 201, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# page done 18
# {'Expert': 167, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 201, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# Hamburgers Hamburgers
# page done 19
# {'Expert': 168, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 201, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# page done 20
# {'Expert': 168, 'Unrated,': 227, 'Newbie': 228, 'Specialist': 201, 'Pupil': 207, 'Candidate': 52, 'Dark_Army': 1, 'Master': 17, 'Grandmaster': 6, 'International': 2, 'tucchiTeam': 2, 'XtraTime': 1, 'The': 1, 'rand(m);': 1}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-38b962d4280a> in <module>()
#      14     purl = td[1].a['href']
#      15     ppage = html(purl)
# ---> 16     cfpage(ppage,name)
#      17     print('DONE WITH A PROBLEM')
#      18
#
# <ipython-input-23-5359cb091e8b> in cfpage(page, name)
#     101         pageurl = contest_url + '/page/' + str(i) + '?order=BY_JUDGED_DESC'
#     102         status_page = html(pageurl)
# --> 103         eachpage(status_page,name)
#     104         print('page done',i)
#     105         print(totalusertype)
#
# <ipython-input-23-5359cb091e8b> in eachpage(status_page, name)
#      82                     except:
#      83                         totalusertype[usertype] = 1
# ---> 84                     processproblem(sollink,problink,exe,mem,usertype)
#      85                     print(name,problemname)
#      86
#
# <ipython-input-23-5359cb091e8b> in processproblem(link, problink, exe, mem, usertype)
#      30 def processproblem(link,problink,exe,mem,usertype):
#      31     global globalcnt
# ---> 32     page = html(link)
#      33     pre = page.find_all('pre',class_='prettyprint lang-cpp program-source')
#      34     code =  pre[0].text
#
# <ipython-input-23-5359cb091e8b> in html(url)
#      24
#      25 def html(url):
# ---> 26     page = requests.get(url)
#      27     soup = BeautifulSoup(page.content,'html.parser')
#      28     return soup
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:

# %%
import json
