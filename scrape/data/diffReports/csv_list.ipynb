# %%
import os

# %%
dirs = []
for i,j,y in os.walk('.'):
    dirs = j
    break
dirs.pop(0)
dirs
# Out:
# ['Akash', 'Harshit', 'Kailash', 'Mukesh']

# %% [markdown]
# # Testing

# %%
f = []
for (dirpath, dirnames, filenames) in os.walk('./Akash'):
    f.extend(filenames)
    break
f
# Out:
# ['-zheksenov-_report.html',
#  'Respect2D_report.html',
#  'resting_prince_report.html',
#  'retRet_report.html',
#  'Riccccchard_report.html',
#  'Rifat448_report.html',
#  'risengo_report.html',
#  'ritik_patel05_report.html',
#  'riyasaat_report.html',
#  'rkasp_report.html',
#  'Rm6_report.html',
#  'Robis2019_report.html',
#  'Rods_report.html',
#  'RogerD_report.html',
#  'rogerpatel_2401_report.html',
#  'Rokham_report.html',
#  'Royhero_report.html',
#  'ruchit_vithani_report.html',
#  'rvsmr_report.html',
#  'ryorda_report.html',
#  'SaikatS_report.html',
#  'Saiphani724_report.html',
#  'Saket1612_report.html',
#  'sakhiya07_report.html',
#  'saksham__27_report.html',
#  'sakshi1811_report.html',
#  'san1201_report.html',
#  'SandInMyHand_report.html',
#  'Sanket17_report.html',
#  'sanyam.ss99_report.html',
#  'saumya_shah_report.html',
#  'Scissors_Ss_report.html',
#  'sdpsarker88_report.html',
#  'Seremo_report.html',
#  'Seyn_report.html',
#  'sgupta98_report.html',
# ...

# %%
mylist = []

for i in f:
    name = i[:-12]
    print(name)
    mylist.append(name)
# Out:
# -zheksenov-
# Respect2D
# resting_prince
# retRet
# Riccccchard
# Rifat448
# risengo
# ritik_patel05
# riyasaat
# rkasp
# Rm6
# Robis2019
# Rods
# RogerD
# rogerpatel_2401
# Rokham
# Royhero
# ruchit_vithani
# rvsmr
# ryorda
# SaikatS
# Saiphani724
# Saket1612
# sakhiya07
# saksham__27
# sakshi1811
# san1201
# SandInMyHand
# Sanket17
# sanyam.ss99
# saumya_shah
# Scissors_Ss
# sdpsarker88
# Seremo
# Seyn
# sgupta98
# shadowoneZeroone
# shahkushal9148
# shankamboj
# shanto_kundu
# shbhmgl
# shell_wataru
# shenji
# sherifmowafy_
# shixuan
# Shtubik
# shy1314
# sifat_15
# Sintac
# sj144
# sjd0
# sky666
# SMit_mangukiya
# sneffort
# soapy_bubble
# Sofianelewin
# spop
# squidward
# starbis
# Strive9881
# subtask
# sunhy
# sushant3524
# Suzukaze_Kiseki
# s_kill
# TamimEhsan
# tamtam
# tasnidmahin
# Tathagat_shah
# teexone
# The_Lost_Desu
# Tiagodsf
# tim.1758
# tiojuan
# TJPU_Hank
# tony29699
# toted
# trancaothaix4
# ttw1018
# tuna_fly
# tushar_nstu
# twtynije1
# uday_dosajh
# udc321
# ...

# %%
with open('test.csv', 'w') as f:
    for item in mylist:
        f.write("%s\n" % item)

# %% [markdown]
# # Processing

# %%
for user in dirs:
    f = []
    for (dirpath, dirnames, filenames) in os.walk('./' + user):
        f.extend(filenames)
        break
    
    mylist = []
    for i in f:
        name = i[:-12]
        mylist.append(name)
    
    with open('./' + user + '/REPORT.csv', 'w') as f:
        for item in mylist:
            f.write("%s\n" % item)
