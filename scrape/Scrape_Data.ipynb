# %%
import requests
from bs4 import BeautifulSoup
import os

globalcnt = 1
ignlist = []
totalusertype = {}

def html(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content,'html.parser')
    return soup

def processproblem(link,problink,exe,mem,usertype):
    global globalcnt
    page = html(link)
    pre = page.find_all('pre',class_='prettyprint lang-cpp program-source')
    code =  pre[0].text
    te = code.strip()
    ext = '.cpp'
    try:
        filename = 'E:\Codes\Code Analysis\CodesNew' + '\\' + str(globalcnt) + ext
        filename2 = 'E:\Codes\Code Analysis\CodesNew' + '\\' + str(globalcnt) + '.json'
        globalcnt+=1
        f = open(filename,"w")
        f.write(code)
        f.close()
        tdict = {}
        tdict["problemlink"] = problink
        tdict["sollink"] = link
        tdict["exec_time"] = exe
        tdict["memory"] = mem
        tdict["usertype"] = usertype
        g = open(filename2,"w")
        json.dump(tdict,g)
        g.close()
    except:
        print('error')


def eachpage(status_page,name):
    global ignlist
    global totalusertype
    status_table = status_page.findAll('table',class_='status-frame-datatable')
    tr = status_table[0].findAll('tr')
    tr.pop(0)
    for i in tr:
        td = i.findAll('td')
        sollink = 'https://www.codeforces.com' + td[0].a['href']
        usertype = td[2].a['title'].split(' ')[0]
        problemname = td[3].a.text.split('-')[-1].strip()
        lang = td[4].text.strip()
        exe = td[6].text.strip()
        mem = td[7].text.strip()
        problink = 'https://www.codeforces.com' + td[3].a['href']
        status = td[5].span['submissionverdict'].strip()
#         if usertype != 'Unrated,' and usertype != 'Pupil' and usertype != 'Specialist' and usertype != 'Newbie':
#             print(status,usertype,problemname,name,lang)
        if usertype not in ignlist:
            if lang == 'GNU C++17' or lang == 'GNU C++14' or lang == 'GNU C++11' or lang == 'GNU C++':
                if status == 'OK' and problemname == name:
                    try:
                        totalusertype[usertype]+=1
                        if totalusertype[usertype] > 200:
                            ignlist.append(usertype)
                    except:
                        totalusertype[usertype] = 1
                    processproblem(sollink,problink,exe,mem,usertype)
                    print(name,problemname)
    
    
                
                
    
def cfpage(page,name):
    global totalusertype
    contest_table = page.findAll('table',class_='rtable ')
    contest_url = contest_table[0].tbody.tr.a['href']
    contest_url = 'https://www.codeforces.com' + contest_url + '/status'
    status_page = html(contest_url)
    pagination = status_page.findAll('div',class_='pagination')
    li = pagination[1].ul.findAll('li')[-2]
    totpage = int(li.span.a.text)
    for i in range(1,min(totpage,200)):
        pageurl = contest_url + '/page/' + str(i) + '?order=BY_JUDGED_DESC'
        status_page = html(pageurl)
        eachpage(status_page,name)
        print('page done',i)
        print(totalusertype)

# %%
stopurl = 'https://www.stopstalk.com/problems/tag?page=1&generalized_tags=Binary+Search&site=CodeForces&orderby=solved-count-desc'

stopsoup = html(stopurl)
main_table = stopsoup.find_all('table',class_='bordered centered')
tbody = main_table[0].tbody

tr = tbody.findAll('tr')

for j in range(1,len(tr)):
    i = tr[j]
    td = i.findAll('td')
    name = td[0].a.text.strip()
    purl = td[1].a['href']
    ppage = html(purl)
    cfpage(ppage,name)
    print('DONE WITH A PROBLEM')
# Out:
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# {'Expert': 5, 'Unrated,': 53, 'Newbie': 19, 'Specialist': 7, 'Pupil': 27, 'Candidate': 1}
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# page done 13
# {'Expert': 5, 'Unrated,': 54, 'Newbie': 21, 'Specialist': 10, 'Pupil': 28, 'Candidate': 1}
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# page done 14
# {'Expert': 6, 'Unrated,': 57, 'Newbie': 26, 'Specialist': 10, 'Pupil': 29, 'Candidate': 1}
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# Vanya and Lanterns Vanya and Lanterns
# page done 15
# {'Expert': 6, 'Unrated,': 60, 'Newbie': 27, 'Specialist': 12, 'Pupil': 31, 'Candidate': 1}
# Vanya and Lanterns Vanya and Lanterns
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a836943c69d7> in <module>()
#      13     purl = td[1].a['href']
#      14     ppage = html(purl)
# ---> 15     cfpage(ppage,name)
#      16     print('DONE WITH A PROBLEM')
#      17
#
# <ipython-input-8-2aef7cc2f0aa> in cfpage(page, name)
#      85         pageurl = contest_url + '/page/' + str(i) + '?order=BY_JUDGED_DESC'
#      86         status_page = html(pageurl)
# ---> 87         eachpage(status_page,name)
#      88         print('page done',i)
#      89         print(totalusertype)
#
# <ipython-input-8-2aef7cc2f0aa> in eachpage(status_page, name)
#      66                     except:
#      67                         totalusertype[usertype] = 1
# ---> 68                     processproblem(sollink,problink,exe,mem,usertype)
#      69                     print(name,problemname)
#      70
#
# <ipython-input-8-2aef7cc2f0aa> in processproblem(link, problink, exe, mem, usertype)
#      14 def processproblem(link,problink,exe,mem,usertype):
#      15     global globalcnt
# ---> 16     page = html(link)
#      17     pre = page.find_all('pre',class_='prettyprint lang-cpp program-source')
#      18     code =  pre[0].text
#
# <ipython-input-8-2aef7cc2f0aa> in html(url)
#       8
#       9 def html(url):
# ---> 10     page = requests.get(url)
#      11     soup = BeautifulSoup(page.content,'html.parser')
#      12     return soup
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     216                     proxies=proxies,
#     217                     allow_redirects=False,
# --> 218                     **adapter_kwargs
#     219                 )
#     220
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     327         context.load_cert_chain(certfile, keyfile)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#     331     warnings.warn(
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     405                          suppress_ragged_eofs=suppress_ragged_eofs,
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#     409     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     812                         # non-blocking
#     813                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 814                     self.do_handshake()
#     815
#     816             except (OSError, ValueError):
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\ssl.py in do_handshake(self, block)
#    1066             if timeout == 0.0 and block:
#    1067                 self.settimeout(None)
# -> 1068             self._sslobj.do_handshake()
#    1069         finally:
#    1070             self.settimeout(timeout)
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\ssl.py in do_handshake(self)
#     687     def do_handshake(self):
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#     691             if not self.server_hostname:
#
# KeyboardInterrupt:

# %%
import json
