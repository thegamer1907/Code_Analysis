# %%
import requests
from bs4 import BeautifulSoup
import os
import json
import time
import calendar
import traceback
import pickle
errcnt = 0
globalcnt = 0
pickle_list = []

# %%
def html(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content,'html.parser')
    return soup


def processproblem(link,problink,exe,mem,usertype,username):
    global errcnt
    global globalcnt
    page = html(link)
    pre = page.find_all('pre',class_='prettyprint lang-cpp program-source')
    code =  pre[0].text
    te = code.strip()
    ext = '.cpp'
    try:
        fname = str(calendar.timegm(time.gmtime()))
        filename = 'C:\git\code_analysis\contest' + '\\' + fname + ext
        filename2 = 'C:\git\code_analysis\contest' + '\\' + fname + '.json'
        f = open(filename,"w")
        f.write(code)
        f.close()
        globalcnt+=1
        tdict = {}
        tdict["problemlink"] = problink
        tdict["sollink"] = link
        tdict["exec_time"] = exe
        tdict["memory"] = mem
        tdict["usertype"] = usertype
        tdict["username"] = username
        g = open(filename2,"w")
        json.dump(tdict,g)
        g.close()
    except Exception as e:
        print(str(e))
        errcnt+=1




def eachpage(status_page):
    global globalcnt
    global pickle_list
    status_table = status_page.findAll('table',class_='status-frame-datatable')
    tr = status_table[0].findAll('tr')
    tr.pop(0)
    for i in tr:
        td = i.findAll('td')
        sollink = 'https://www.codeforces.com' + td[0].a['href']
        if sollink in pickle_list:
            globalcnt+=1
            continue
        usertype = td[2].a['title'].split(' ')[0]
        username = td[2].a.text.strip()
        problemname = td[3].a.text.split('-')[-1].strip()
        lang = td[4].text.strip()
        exe = td[6].text.strip()
        mem = td[7].text.strip()
        problink = 'https://www.codeforces.com' + td[3].a['href']
        status = td[5].span['submissionverdict'].strip()
#         if usertype != 'Unrated,' and usertype != 'Pupil' and usertype != 'Specialist' and usertype != 'Newbie':
#             print(status,usertype,problemname,name,lang)
        if lang == 'GNU C++17' or lang == 'GNU C++14' or lang == 'GNU C++11' or lang == 'GNU C++':
            if status == 'OK':
                pickle_list.append(sollink)
                processproblem(sollink,problink,exe,mem,usertype,username)
                print('done with',globalcnt)





def cfpage():
    global pickle_list
    with open('pickle_list.pkl', 'rb') as f:
        pickle_list = pickle.load(f)
    contest_url = 'https://codeforces.com/contest/868/status'
    status_page = html(contest_url)
    pagination = status_page.findAll('div',class_='pagination')
    li = pagination[1].ul.findAll('li')[-2]
    totpage = int(li.span.a.text)
    for i in range(1,totpage+1):
        pageurl = contest_url + '/page/' + str(i) + '?order=BY_JUDGED_DESC'
        status_page = html(pageurl)
        eachpage(status_page)
        print('page done',i)

# %%
try:
    cfpage()
except Exception as e:
    print(str(e))
    traceback.print_tb(e.__traceback__)
    with open('pickle_list.pkl', 'wb') as f:
        pickle.dump(pickle_list, f)
# Out:
# page done 1
# page done 2
# page done 3
# page done 4
# page done 5
# page done 6
# page done 7
# page done 8
# page done 9
# page done 10
# page done 11
# page done 12
# page done 13
# page done 14
# page done 15
# page done 16
# page done 17
# page done 18
# page done 19
# page done 20
# page done 21
# page done 22
# page done 23
# page done 24
# page done 25
# page done 26
# page done 27
# page done 28
# page done 29
# page done 30
# page done 31
# done with 1787
# done with 1788
# done with 1789
# page done 120
# done with 1790
# done with 1791
# done with 1792
# done with 1793
# page done 121
# done with 1794
# 'charmap' codec can't encode characters in position 542-555: character maps to <undefined>
# done with 1794
# done with 1795
# done with 1796
# done with 1797
# done with 1798
# done with 1799
# done with 1800
# done with 1801
# 'charmap' codec can't encode characters in position 82-90: character maps to <undefined>
# done with 1801
# done with 1802
# done with 1803
# done with 1804
# done with 1805
# page done 122
# done with 1806
# done with 1807
# done with 1808
# done with 1809
# done with 1810
# done with 1811
# done with 1812
# done with 1813
# done with 1814
# done with 1815
# done with 1816
# page done 123
# 'charmap' codec can't encode characters in position 53-60: character maps to <undefined>
# done with 1816
# done with 1817
# done with 1818
# done with 1819
# done with 1820
# done with 1821
# done with 1822
# done with 1823
# done with 1824
# done with 1825
# done with 1826
# done with 1827
# done with 1828
# done with 1829
# done with 1830
# done with 1831
# done with 1832
# page done 124
# done with 1833
# done with 1834
# done with 1835
# done with 1836
# done with 1837
# done with 1838
# done with 1839
# done with 1840
# done with 1841
# done with 1842
# done with 1843
# done with 1844
# page done 125
# done with 1845
# done with 1846
# done with 1847
# done with 1848
# 'charmap' codec can't encode characters in position 1209-1240: character maps to <undefined>
# done with 1848
# done with 1849
# done with 1850
# done with 1851
# 'charmap' codec can't encode characters in position 1703-1709: character maps to <undefined>
# done with 1851
# page done 126
# done with 1852
# done with 1853
# done with 1854
# done with 1855
# done with 1856
# done with 1857
# done with 1858
# done with 1859
# done with 1860
# done with 1861
# done with 1862
# done with 1863
# page done 127
# done with 1864
# done with 1865
# done with 1866
# done with 1867
# done with 1868
# done with 1869
# done with 1870
# done with 1871
# done with 1872
# ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
#   File "<ipython-input-7-e9cb89197a9c>", line 2, in <module>
#     cfpage()
#   File "<ipython-input-6-5eea2381df5a>", line 84, in cfpage
#     eachpage(status_page)
#   File "<ipython-input-6-5eea2381df5a>", line 65, in eachpage
#     processproblem(sollink,problink,exe,mem,usertype,username)
#   File "<ipython-input-6-5eea2381df5a>", line 10, in processproblem
#     page = html(link)
#   File "<ipython-input-6-5eea2381df5a>", line 2, in html
#     page = requests.get(url)
#   File "c:\users\akash\appdata\local\programs\python\python36\lib\site-packages\requests\api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "c:\users\akash\appdata\local\programs\python\python36\lib\site-packages\requests\api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "c:\users\akash\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "c:\users\akash\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py", line 668, in send
#     history = [resp for resp in gen] if allow_redirects else []
#   File "c:\users\akash\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py", line 668, in <listcomp>
#     history = [resp for resp in gen] if allow_redirects else []
#   File "c:\users\akash\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py", line 247, in resolve_redirects
#     **adapter_kwargs
#   File "c:\users\akash\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "c:\users\akash\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)

# %%
with open('pickle_list.pkl', 'rb') as f:
        pl2 = pickle.load(f)
print(len(pl2))
# Out:
# 1899
