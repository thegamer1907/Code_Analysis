# %%
import requests
from bs4 import BeautifulSoup
import os

globalcnt = 1048

def html(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content,'html.parser')
    return soup

def processproblem(link):
    global globalcnt
    page = html(link)
    pre = page.find_all('pre',class_='prettyprint lang-cpp program-source')
    code =  pre[0].text
    te = code.strip()
    ext = '.cpp'
    try:
        filename = 'E:\Codes\Code Analysis\Codes' + '\\' + str(globalcnt) + ext
        globalcnt+=1
        f = open(filename,"w")
        f.write(code)
        f.close()
    except:
        print('error')


def eachpage(status_page,name):
    status_table = status_page.findAll('table',class_='status-frame-datatable')
    tr = status_table[0].findAll('tr')
    tr.pop(0)
    for i in tr:
        td = i.findAll('td')
        sollink = 'https://www.codeforces.com' + td[0].a['href']
        usertype = td[2].a['title'].split(' ')[0]
        problemname = td[3].a.text.split('-')[-1].strip()
        lang = td[4].text.strip()
        status = td[5].span['submissionverdict'].strip()
        if usertype != 'Unrated,' and usertype != 'Pupil' and usertype != 'Specialist' and usertype != 'Newbie':
#             print(status,usertype,problemname,name,lang)
            if lang == 'GNU C++17' or lang == 'GNU C++14' or lang == 'GNU C++11' or lang == 'GNU C++':
                if status == 'OK' and problemname == name:
                    processproblem(sollink)
                    print(name,problemname)
    
    
                
                
    
def cfpage(page,name):
    contest_table = page.findAll('table',class_='rtable ')
    contest_url = contest_table[0].tbody.tr.a['href']
    contest_url = 'https://www.codeforces.com' + contest_url + '/status'
    status_page = html(contest_url)
    pagination = status_page.findAll('div',class_='pagination')
    li = pagination[1].ul.findAll('li')[-2]
    totpage = int(li.span.a.text)
    for i in range(1,min(totpage,400)):
        pageurl = contest_url + '/page/' + str(i) + '?order=BY_JUDGED_DESC'
        status_page = html(pageurl)
        eachpage(status_page,name)
        print('page done',i)

# %%
stopurl = 'https://www.stopstalk.com/problems/tag?page=1&generalized_tags=Binary+Search&site=CodeForces&orderby=solved-count-desc'

stopsoup = html(stopurl)
main_table = stopsoup.find_all('table',class_='bordered centered')
tbody = main_table[0].tbody

tr = tbody.findAll('tr')

for j in range(8,len(tr)):
    i = tr[j]
    td = i.findAll('td')
    name = td[0].a.text.strip()
    purl = td[1].a['href']
    ppage = html(purl)
    cfpage(ppage,name)
    print('DONE WITH A PROBLEM')
# Out:
# page done 1
# page done 2
# page done 3
# page done 4
# page done 5
# Kefa and Company Kefa and Company
# page done 6
# page done 7
# page done 8
# page done 9
# page done 10
# page done 11
# page done 12
# page done 13
# page done 14
# page done 15
# Kefa and Company Kefa and Company
# page done 16
# page done 17
# page done 18
# page done 19
# Kefa and Company Kefa and Company
# page done 20
# page done 21
# page done 22
# page done 23
# page done 24
# Kefa and Company Kefa and Company
# page done 25
# page done 26
# Kefa and Company Kefa and Company
# page done 27
# page done 28
# page done 29
# page done 30
# page done 31
# page done 32
# page done 33
# page done 34
# page done 35
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 36
# page done 37
# page done 38
# page done 39
# page done 40
# page done 41
# page done 42
# page done 43
# page done 44
# page done 45
# page done 46
# page done 47
# page done 48
# page done 49
# page done 50
# page done 51
# page done 52
# Kefa and Company Kefa and Company
# page done 53
# page done 54
# Kefa and Company Kefa and Company
# page done 55
# page done 56
# page done 57
# Kefa and Company Kefa and Company
# page done 58
# page done 59
# page done 60
# page done 61
# page done 62
# page done 63
# page done 64
# page done 65
# page done 66
# page done 67
# page done 68
# page done 69
# Kefa and Company Kefa and Company
# page done 70
# page done 71
# page done 72
# page done 73
# Kefa and Company Kefa and Company
# page done 74
# page done 75
# page done 76
# Kefa and Company Kefa and Company
# page done 77
# Kefa and Company Kefa and Company
# page done 78
# page done 79
# page done 80
# page done 81
# page done 82
# Kefa and Company Kefa and Company
# page done 83
# Kefa and Company Kefa and Company
# page done 84
# page done 85
# page done 86
# Kefa and Company Kefa and Company
# page done 87
# Kefa and Company Kefa and Company
# page done 88
# Kefa and Company Kefa and Company
# page done 89
# page done 90
# Kefa and Company Kefa and Company
# page done 91
# Kefa and Company Kefa and Company
# page done 92
# page done 93
# page done 94
# page done 95
# page done 96
# page done 97
# page done 98
# page done 99
# page done 100
# page done 101
# page done 102
# page done 103
# page done 104
# page done 105
# page done 106
# page done 107
# page done 108
# page done 109
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 110
# page done 111
# Kefa and Company Kefa and Company
# page done 112
# Kefa and Company Kefa and Company
# page done 113
# page done 114
# page done 115
# page done 116
# page done 117
# page done 118
# page done 119
# page done 120
# page done 121
# page done 122
# Kefa and Company Kefa and Company
# page done 123
# page done 124
# page done 125
# page done 126
# page done 127
# page done 128
# page done 129
# page done 130
# Kefa and Company Kefa and Company
# page done 131
# page done 132
# page done 133
# Kefa and Company Kefa and Company
# page done 134
# page done 135
# page done 136
# page done 137
# page done 138
# page done 139
# Kefa and Company Kefa and Company
# page done 140
# page done 141
# Kefa and Company Kefa and Company
# page done 142
# Kefa and Company Kefa and Company
# page done 143
# page done 144
# Kefa and Company Kefa and Company
# page done 145
# page done 146
# page done 147
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 148
# Kefa and Company Kefa and Company
# page done 149
# Kefa and Company Kefa and Company
# page done 150
# Kefa and Company Kefa and Company
# page done 151
# page done 152
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 153
# page done 154
# page done 155
# page done 156
# page done 157
# page done 158
# page done 159
# page done 160
# page done 161
# page done 162
# page done 163
# page done 164
# page done 165
# page done 166
# page done 167
# Kefa and Company Kefa and Company
# page done 168
# page done 169
# page done 170
# page done 171
# page done 172
# page done 173
# Kefa and Company Kefa and Company
# page done 174
# page done 175
# Kefa and Company Kefa and Company
# page done 176
# page done 177
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 178
# page done 179
# Kefa and Company Kefa and Company
# page done 180
# page done 181
# page done 182
# page done 183
# Kefa and Company Kefa and Company
# page done 184
# page done 185
# page done 186
# page done 187
# page done 188
# page done 189
# page done 190
# page done 191
# page done 192
# page done 193
# page done 194
# page done 195
# page done 196
# page done 197
# page done 198
# page done 199
# page done 200
# page done 201
# Kefa and Company Kefa and Company
# page done 202
# Kefa and Company Kefa and Company
# page done 203
# page done 204
# Kefa and Company Kefa and Company
# page done 205
# page done 206
# page done 207
# page done 208
# page done 209
# page done 210
# page done 211
# page done 212
# page done 213
# page done 214
# page done 215
# Kefa and Company Kefa and Company
# page done 216
# page done 217
# page done 218
# page done 219
# page done 220
# page done 221
# page done 222
# Kefa and Company Kefa and Company
# page done 223
# page done 224
# page done 225
# Kefa and Company Kefa and Company
# page done 226
# page done 227
# page done 228
# page done 229
# page done 230
# Kefa and Company Kefa and Company
# page done 231
# page done 232
# page done 233
# page done 234
# page done 235
# page done 236
# page done 237
# page done 238
# page done 239
# Kefa and Company Kefa and Company
# page done 240
# page done 241
# Kefa and Company Kefa and Company
# page done 242
# page done 243
# page done 244
# page done 245
# Kefa and Company Kefa and Company
# page done 246
# page done 247
# Kefa and Company Kefa and Company
# page done 248
# page done 249
# page done 250
# page done 251
# page done 252
# page done 253
# page done 254
# Kefa and Company Kefa and Company
# page done 255
# page done 256
# page done 257
# page done 258
# Kefa and Company Kefa and Company
# page done 259
# page done 260
# page done 261
# page done 262
# page done 263
# page done 264
# page done 265
# page done 266
# page done 267
# page done 268
# Kefa and Company Kefa and Company
# page done 269
# page done 270
# page done 271
# page done 272
# page done 273
# page done 274
# page done 275
# page done 276
# page done 277
# page done 278
# page done 279
# page done 280
# page done 281
# page done 282
# page done 283
# page done 284
# page done 285
# page done 286
# page done 287
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 288
# page done 289
# page done 290
# page done 291
# page done 292
# page done 293
# page done 294
# page done 295
# page done 296
# Kefa and Company Kefa and Company
# page done 297
# page done 298
# page done 299
# page done 300
# page done 301
# page done 302
# page done 303
# page done 304
# page done 305
# page done 306
# page done 307
# page done 308
# page done 309
# page done 310
# page done 311
# page done 312
# page done 313
# page done 314
# page done 315
# page done 316
# page done 317
# Kefa and Company Kefa and Company
# page done 318
# page done 319
# page done 320
# Kefa and Company Kefa and Company
# page done 321
# page done 322
# page done 323
# page done 324
# Kefa and Company Kefa and Company
# page done 325
# Kefa and Company Kefa and Company
# page done 326
# page done 327
# page done 328
# page done 329
# page done 330
# page done 331
# page done 332
# error
# Kefa and Company Kefa and Company
# page done 333
# page done 334
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 335
# Kefa and Company Kefa and Company
# page done 336
# page done 337
# Kefa and Company Kefa and Company
# page done 338
# Kefa and Company Kefa and Company
# page done 339
# page done 340
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 341
# page done 342
# page done 343
# page done 344
# page done 345
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 346
# Kefa and Company Kefa and Company
# page done 347
# page done 348
# page done 349
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 350
# page done 351
# page done 352
# page done 353
# Kefa and Company Kefa and Company
# page done 354
# Kefa and Company Kefa and Company
# page done 355
# Kefa and Company Kefa and Company
# page done 356
# page done 357
# page done 358
# Kefa and Company Kefa and Company
# page done 359
# page done 360
# page done 361
# page done 362
# page done 363
# page done 364
# Kefa and Company Kefa and Company
# page done 365
# Kefa and Company Kefa and Company
# page done 366
# Kefa and Company Kefa and Company
# page done 367
# page done 368
# page done 369
# page done 370
# page done 371
# Kefa and Company Kefa and Company
# page done 372
# error
# Kefa and Company Kefa and Company
# page done 373
# page done 374
# page done 375
# Kefa and Company Kefa and Company
# page done 376
# Kefa and Company Kefa and Company
# page done 377
# page done 378
# page done 379
# page done 380
# page done 381
# page done 382
# page done 383
# page done 384
# page done 385
# page done 386
# page done 387
# page done 388
# page done 389
# Kefa and Company Kefa and Company
# page done 390
# page done 391
# Kefa and Company Kefa and Company
# page done 392
# page done 393
# Kefa and Company Kefa and Company
# page done 394
# page done 395
# page done 396
# Kefa and Company Kefa and Company
# Kefa and Company Kefa and Company
# page done 397
# page done 398
# page done 399
# DONE WITH A PROBLEM
# PolandBall and Game PolandBall and Game
# page done 1
# PolandBall and Game PolandBall and Game
# page done 2
# page done 3
# page done 4
# PolandBall and Game PolandBall and Game
# page done 5
# PolandBall and Game PolandBall and Game
# page done 6
# page done 7
# page done 8
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 9
# page done 10
# PolandBall and Game PolandBall and Game
# page done 11
# PolandBall and Game PolandBall and Game
# page done 12
# PolandBall and Game PolandBall and Game
# page done 13
# page done 14
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 15
# page done 16
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 17
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 18
# page done 19
# page done 20
# page done 21
# page done 22
# page done 23
# PolandBall and Game PolandBall and Game
# page done 24
# PolandBall and Game PolandBall and Game
# page done 25
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 26
# page done 27
# PolandBall and Game PolandBall and Game
# page done 28
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 29
# PolandBall and Game PolandBall and Game
# page done 30
# PolandBall and Game PolandBall and Game
# page done 31
# page done 32
# PolandBall and Game PolandBall and Game
# page done 33
# PolandBall and Game PolandBall and Game
# page done 34
# page done 35
# page done 36
# PolandBall and Game PolandBall and Game
# page done 37
# page done 38
# page done 39
# PolandBall and Game PolandBall and Game
# page done 40
# page done 41
# page done 42
# page done 43
# page done 44
# page done 45
# page done 46
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 47
# PolandBall and Game PolandBall and Game
# page done 48
# PolandBall and Game PolandBall and Game
# page done 49
# error
# PolandBall and Game PolandBall and Game
# page done 50
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 51
# PolandBall and Game PolandBall and Game
# page done 52
# PolandBall and Game PolandBall and Game
# page done 53
# page done 54
# PolandBall and Game PolandBall and Game
# page done 55
# PolandBall and Game PolandBall and Game
# page done 56
# page done 57
# PolandBall and Game PolandBall and Game
# page done 58
# page done 59
# page done 60
# page done 61
# page done 62
# PolandBall and Game PolandBall and Game
# page done 63
# page done 64
# page done 65
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 66
# page done 67
# page done 68
# page done 69
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 70
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 71
# page done 72
# page done 73
# PolandBall and Game PolandBall and Game
# page done 74
# PolandBall and Game PolandBall and Game
# page done 75
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 76
# PolandBall and Game PolandBall and Game
# page done 77
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# error
# PolandBall and Game PolandBall and Game
# page done 78
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 79
# PolandBall and Game PolandBall and Game
# page done 80
# page done 81
# PolandBall and Game PolandBall and Game
# page done 82
# PolandBall and Game PolandBall and Game
# page done 83
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 84
# PolandBall and Game PolandBall and Game
# page done 85
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 86
# page done 87
# PolandBall and Game PolandBall and Game
# page done 88
# PolandBall and Game PolandBall and Game
# page done 89
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 90
# page done 91
# PolandBall and Game PolandBall and Game
# page done 92
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 93
# PolandBall and Game PolandBall and Game
# page done 94
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 95
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 96
# page done 97
# page done 98
# page done 99
# page done 100
# PolandBall and Game PolandBall and Game
# page done 101
# page done 102
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 103
# page done 104
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 105
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 106
# PolandBall and Game PolandBall and Game
# page done 107
# page done 108
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 109
# page done 110
# page done 111
# page done 112
# page done 113
# page done 114
# PolandBall and Game PolandBall and Game
# page done 115
# page done 116
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 117
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 118
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 119
# page done 120
# page done 121
# page done 122
# page done 123
# page done 124
# page done 125
# PolandBall and Game PolandBall and Game
# page done 126
# page done 127
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 128
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 129
# PolandBall and Game PolandBall and Game
# page done 130
# PolandBall and Game PolandBall and Game
# page done 131
# PolandBall and Game PolandBall and Game
# page done 132
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 133
# page done 134
# PolandBall and Game PolandBall and Game
# page done 135
# PolandBall and Game PolandBall and Game
# page done 136
# page done 137
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 138
# PolandBall and Game PolandBall and Game
# page done 139
# page done 140
# page done 141
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 142
# page done 143
# PolandBall and Game PolandBall and Game
# page done 144
# PolandBall and Game PolandBall and Game
# page done 145
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 146
# PolandBall and Game PolandBall and Game
# page done 147
# page done 148
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 149
# page done 150
# page done 151
# page done 152
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 153
# PolandBall and Game PolandBall and Game
# page done 154
# PolandBall and Game PolandBall and Game
# page done 155
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 156
# PolandBall and Game PolandBall and Game
# page done 157
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 158
# PolandBall and Game PolandBall and Game
# page done 159
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 160
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 161
# PolandBall and Game PolandBall and Game
# page done 162
# page done 163
# PolandBall and Game PolandBall and Game
# page done 164
# page done 165
# PolandBall and Game PolandBall and Game
# page done 166
# page done 167
# PolandBall and Game PolandBall and Game
# page done 168
# PolandBall and Game PolandBall and Game
# page done 169
# page done 170
# PolandBall and Game PolandBall and Game
# page done 171
# PolandBall and Game PolandBall and Game
# page done 172
# PolandBall and Game PolandBall and Game
# page done 173
# PolandBall and Game PolandBall and Game
# page done 174
# PolandBall and Game PolandBall and Game
# error
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 175
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 176
# PolandBall and Game PolandBall and Game
# page done 177
# page done 178
# PolandBall and Game PolandBall and Game
# page done 179
# page done 180
# PolandBall and Game PolandBall and Game
# page done 181
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 182
# PolandBall and Game PolandBall and Game
# page done 183
# PolandBall and Game PolandBall and Game
# page done 184
# page done 185
# page done 186
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 187
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 188
# page done 189
# PolandBall and Game PolandBall and Game
# page done 190
# page done 191
# PolandBall and Game PolandBall and Game
# PolandBall and Game PolandBall and Game
# page done 192
# PolandBall and Game PolandBall and Game
# page done 193
# PolandBall and Game PolandBall and Game
# page done 194
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d306da96b4ac> in <module>()
#      13     purl = td[1].a['href']
#      14     ppage = html(purl)
# ---> 15     cfpage(ppage,name)
#      16     print('DONE WITH A PROBLEM')
#      17
#
# <ipython-input-1-e726d0f64ec6> in cfpage(page, name)
#      60         pageurl = contest_url + '/page/' + str(i) + '?order=BY_JUDGED_DESC'
#      61         status_page = html(pageurl)
# ---> 62         eachpage(status_page,name)
#      63         print('page done',i)
#      64
#
# <ipython-input-1-e726d0f64ec6> in eachpage(status_page, name)
#      42             if lang == 'GNU C++17' or lang == 'GNU C++14' or lang == 'GNU C++11' or lang == 'GNU C++':
#      43                 if status == 'OK' and problemname == name:
# ---> 44                     processproblem(sollink)
#      45                     print(name,problemname)
#      46
#
# <ipython-input-1-e726d0f64ec6> in processproblem(link)
#      12 def processproblem(link):
#      13     global globalcnt
# ---> 14     page = html(link)
#      15     pre = page.find_all('pre',class_='prettyprint lang-cpp program-source')
#      16     code =  pre[0].text
#
# <ipython-input-1-e726d0f64ec6> in html(url)
#       6
#       7 def html(url):
# ----> 8     page = requests.get(url)
#       9     soup = BeautifulSoup(page.content,'html.parser')
#      10     return soup
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# c:\users\harshit agarwal\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:
